# %%
used = 30+36+38 + 1.5 + 6.3 * 2
potential_pos = 6.3 * 3 * 2 
potential_neg = potential_pos
sc_pot = 3 * 17
vel = 1.5 
#low_res_neg = 1.6 * 20
sum = used + potential_pos + potential_neg + sc_pot + vel
print('estimated cost is:', sum)
# Out:
# estimated cost is: 246.2
